# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

import pandas as pd
uri = "https://raw.githubusercontent.com/TanKinWah/Arquivos_python/master/Inadimplencia_cc.csv"

df = pd.read_csv(uri, encoding='iso-8859-1', delimiter = ';')

df["Credito pessoal total"]= df["Credito pessoal total"].str.replace(',', ".").astype(str)
df["Credito pessoal consignado"]= df["Credito pessoal consignado"].str.replace(',', ".").astype(float)
df["Credito pessoal não consignado"]= df["Credito pessoal não consignado"].str.replace(',', ".").astype(float)
df["data"]= df["data"].apply(pd.to_datetime)

fig = px.line(df, x='data', y='Credito pessoal total')
fig.show()
# Out:
# <div>
#
#
#             <div id="f255d122-1f72-4583-af74-b0861e6f9542" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f255d122-1f72-4583-af74-b0861e6f9542")) {
#                     Plotly.newPlot(
#                         'f255d122-1f72-4583-af74-b0861e6f9542',
# ...

# %%
import plotly.express as px

import pandas as pd
fig = px.line(df, x='data', y='Credito pessoal total')
fig.show()
# Out:
# <div>
#
#
#             <div id="e3ab7579-6dd0-4d72-8422-d2796b9147c1" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e3ab7579-6dd0-4d72-8422-d2796b9147c1")) {
#                     Plotly.newPlot(
#                         'e3ab7579-6dd0-4d72-8422-d2796b9147c1',
# ...

# %%
import plotly.express as px
#Transformando em ano

uri = "https://raw.githubusercontent.com/TanKinWah/Arquivos_python/master/Inadimplencia_cc.csv"

df = pd.read_csv(uri, encoding='iso-8859-1', delimiter = ';')

df["Credito pessoal total"]= df["Credito pessoal total"].str.replace(',', ".").astype(str)
df["Credito pessoal consignado"]= df["Credito pessoal consignado"].str.replace(',', ".").astype(float)
df["Credito pessoal não consignado"]= df["Credito pessoal não consignado"].str.replace(',', ".").astype(float)
df["data"]= df["data"].apply(pd.to_datetime)
df["data"]= (df['data']).dt.year
#Plotar boxplot
fig = px.box(df, x="data", y="Credito pessoal total", points="all")
fig.show()
# Out:
# <div>
#
#
#             <div id="9c6cc995-5cea-48e3-bedf-51b8643b1ea4" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c6cc995-5cea-48e3-bedf-51b8643b1ea4")) {
#                     Plotly.newPlot(
#                         '9c6cc995-5cea-48e3-bedf-51b8643b1ea4',
# ...

# %% [markdown]
# # OCR

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract as ocr
ocr.pytesseract.tesseract_cmd = r'C:\Users\tan_wah\AppData\Local\Tesseract-OCR\tesseract.exe'
from PIL import Image


Image= Image.open('C:/Users/KinWah/Desktop/SOROCRED_ARCHIVE/Identificação_image/passport.png')
Image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=475x682 at 0xC85DC50>

# %%
import pytesseract as ocr
ocr.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
from PIL import Image
phrase = ocr.image_to_string(Image.open('C:/Users/KinWah/Desktop/SOROCRED_ARCHIVE/Identificação_image/passport.png'),lang='por')

print(phrase)
# Out:
# REPUBLICA FEDERATIVA DO BRASIL,
#
# ESTADO DO ESPÍRITO SANTO 678X-01
# SECRETARIA DE ESTADO DE SEGURANÇA PÚBLICA
# POLICIA CIVIL
# [PTC [DEPARTAMENTO DE JoEN
#
# | oarezra zebatoa
#
# dente,
#
# BXKXX-019205 SSSTRTURA DE TITULAR
#
# ERITRO. 52.2X4.654-1 W8SL10 04/DEZ/2021
#
# Nove MARIA EDUARDA DA SILVA
#
# EDUARDO RIBEIRO DA SILVA
# ANA CLAUDIA DA SILVA
#
# VITÓRIA - ES 01/DEZ/1989
# 0 omcem C. NASC "LIV 84X FLS 19X) TERM 14188X co07
# VITÓRIA Es
#
# cm 314.291.255-XX

# %%
import pytesseract as ocr
ocr.pytesseract.tesseract_cmd = r'C:\Users\tan_wah\AppData\Local\Tesseract-OCR\tesseract.exe'
from PIL import Image


Image= Image.open('C:/Users/KinWah/Desktop/SOROCRED_ARCHIVE/Identificação_image/eu.png')
Image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=749x501 at 0x92351D0>

# %%
import pytesseract as ocr
ocr.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
from PIL import Image
phrase = ocr.image_to_string(Image.open('C:/Users/KinWah/Desktop/SOROCRED_ARCHIVE/Identificação_image/eu.png'),lang='por')

print(phrase)
# Out:
# TAN KIN WAH
#
#
#
# DOC. IDENTIDADE / ÓRG. EMISSOR / UF
# 504771127 SSPSP
#
# DATA NASCIMENTO =
# 132. 361 .488- “es(20/10/1996)
#
# FILIAÇÃO
# TAN JIA LIANG
#
#
#
#
# ZHU XIN YOU
#
# PERMISSÃO. ACC CAT. HAB.
# ( mm seno Y B )
#
# VALIDADE 1º HABILITAÇÃO
#
# 03/02/2021 30/05/2016

# %%
import pytesseract as ocr
ocr.pytesseract.tesseract_cmd = r'C:\Users\tan_wah\AppData\Local\Tesseract-OCR\tesseract.exe'
from PIL import Image


Image= Image.open('C:/Users/KinWah/Desktop/SOROCRED_ARCHIVE/Identificação_image/info3.png')
Image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=488x495 at 0x9235748>

# %%
import pytesseract as ocr
ocr.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
from PIL import Image
phrase = ocr.image_to_string(Image.open('C:/Users/KinWah/Desktop/SOROCRED_ARCHIVE/Identificação_image/info3.png'),lang='por')

print(phrase)
# Out:
# ÓRG. EMISSOR / UF
#
# Doc. IDENTIDADE /
# 504771127 ssPSP
#
# CPF DATA NASCIMENTO
# 432.361 .488-88 30/10/1996
#
# FILIAÇÃO
# TAN JIA LIANG
#
# ZHU XIN YOU
#
#
#
# VALIDADE 1º HABILT
# | 03/02/2021 | 30/05/2016 )
